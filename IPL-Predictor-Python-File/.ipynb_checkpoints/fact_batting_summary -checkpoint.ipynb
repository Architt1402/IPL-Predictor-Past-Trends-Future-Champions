# %%
import pandas as pd
import numpy as np

dim_df = pd.read_csv(r'C:/Users/ASUS/Downloads/fact_bating_summary.csv', encoding='cp1252')

# %%
dim_df.columns
# Out:
# Index(['match_id', 'match', 'teamInnings', 'battingPos', 'batsmanName',
#        'out/not_out', 'runs', 'balls', '4s', '6s', 'SR', 'Unnamed: 11'],
#       dtype='object')

# %%
dim_df = dim_df.loc[:, ~dim_df.columns.str.contains('^Unnamed')]

# %%
dim_df.columns
# Out:
# Index(['match_id', 'match', 'teamInnings', 'battingPos', 'batsmanName',
#        'out/not_out', 'runs', 'balls', '4s', '6s', 'SR'],
#       dtype='object')

# %%
dim_df.head(10)
# Out:
#   match_id                  match  teamInnings  battingPos        batsmanName  \
# 0  T203878  Super Kings Vs Mumbai  Super Kings         1.0     RuturajGaikwad
# 1  T203878  Super Kings Vs Mumbai  Super Kings         2.0        DevonConway
# 2  T203878  Super Kings Vs Mumbai  Super Kings         3.0           MoeenAli
# 3  T203878  Super Kings Vs Mumbai  Super Kings         4.0       RobinUthappa
# 4  T203878  Super Kings Vs Mumbai  Super Kings         5.0       AmbatiRayudu
# 5  T203878  Super Kings Vs Mumbai  Super Kings         6.0            MSDhoni
# 6  T203878  Super Kings Vs Mumbai  Super Kings         7.0         ShivamDube
# 7  T203878  Super Kings Vs Mumbai  Super Kings         8.0        DwayneBravo
# 8  T203878  Super Kings Vs Mumbai  Super Kings         9.0     SimarjeetSingh
# 9  T203878  Super Kings Vs Mumbai  Super Kings        10.0  MaheeshTheekshana
#
#   out/not_out runs  balls   4s   6s      SR
# 0         out    7    6.0  1.0  0.0  116.66
# 1         out    0    1.0  0.0  0.0       0
# 2         out    0    2.0  0.0  0.0       0
# 3         out    1    6.0  0.0  0.0   16.66
# 4         out   10   14.0  2.0  0.0   71.42
# 5     not_out   36   33.0  4.0  2.0  109.09
# 6         out   10    9.0  1.0  0.0  111.11
# 7         out   12   15.0  0.0  1.0      80
# 8         out    2    3.0  0.0  0.0   66.66
# 9         out    0    3.0  0.0  0.0       0

# %%
dim_df.tail(10)
# Out:
#      match_id                                         match teamInnings  \
# 3215  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         SRH
# 3216  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         SRH
# 3217  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         SRH
# 3218  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         SRH
# 3219  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         SRH
# 3220  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         SRH
# 3221  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         KKR
# 3222  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         KKR
# 3223  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         KKR
# 3224  T203332  Kolkata Knight Riders VS Sunrisers Hyderabad         KKR
#
#       battingPos         batsmanName out/not_out runs  balls   4s   6s      SR
# 3215         6.0    Heinrich Klaasen         out   16   17.0  1.0  0.0   94.12
# 3216         7.0       Shahbaz Ahmed         out    8    7.0  0.0  1.0  114.29
# 3217         8.0         Abdul Samad         out    4    4.0  0.0  0.0     100
# 3218         9.0         Pat Cummins         out   24   19.0  2.0  1.0  126.32
# 3219        10.0      Jaydev Unadkat         out    4   11.0  0.0  0.0   36.36
# 3220        11.0   Bhuvneshwar Kumar     not_out    0    1.0  0.0  0.0       0
# 3221         1.0  Rahmanullah Gurbaz         out   39   32.0  5.0  2.0  121.88
# 3222         2.0        Sunil Narine         out    6    2.0  0.0  1.0     300
# 3223         3.0      Venkatesh Iyer     not_out   52   26.0  4.0  3.0     200
# 3224         4.0        Shreyas Iyer     not_out    6    3.0  1.0  0.0     200

# %%
dim_df.shape
# Out:
# (3225, 11)

# %%
# Mapping of short or alternate names to full team names
team_name_map = {
    'KKR': 'Kolkata Knight Riders',
    'RCB': 'Royal Challengers Bangalore',
    'mi': 'Mumbai Indians',
    'MI': 'Mumbai Indians',
    'Mumbai':'Mumbai Indians',
    'Capitals': 'Delhi Capitals',
    'DC': 'Delhi Capitals',
    'Punjab Kings': 'Punjab Kings',
    'Super Kings': 'Chennai Super Kings',
    'CSK': 'Chennai Super Kings',
    'Royals': 'Rajasthan Royals',
    'RR': 'Rajasthan Royals',
    'Sunrisers': 'Sunrisers Hyderabad',
    'SRH': 'Sunrisers Hyderabad',
    'Titans': 'Gujarat Titans',
    'GT': 'Gujarat Titans',
    'Super Giants': 'Lucknow Super Giants',
    'LSG': 'Lucknow Super Giants',
    'rcb': 'Royal Challengers Bengaluru',
    'rr': 'Rajasthan Royals',
    'srh': 'Sunrisers Hyderabad',
    'pk': 'Punjab Kings',
    'lsg': 'Lucknow Super Giants',
    'csk': 'Chennai Super Kings',
    'kkr': 'Kolkata Knight Riders',
    'gt': 'Gujarat Titans',
    'dc': 'Delhi Capitals',
    'lrg': 'Lucknow Super Giants',
    'kolkata':'Kolkata Knight Riders',
    'rajasthan':'Rajasthan Royals',
    'gujrat':'Gujarat Titans',
    'Royal Challengers Bangalore':'Royal Challengers Bengaluru'
}

# Apply mapping to all team columns
dim_df['teamInnings'] = dim_df['teamInnings'].replace(team_name_map)
dim_df['match'] = dim_df['match'].replace(team_name_map)

# %%
# Columns to clean
columns_to_clean = ['battingPos', 'runs', 'balls', '4s', '6s']

# Step 1: Remove '*' and convert to float first (in case of '5*')
for col in columns_to_clean:
    dim_df[col] = dim_df[col].astype(str).str.replace('*', '', regex=False)
    dim_df[col] = pd.to_numeric(dim_df[col], errors='coerce').astype('Int64')  # Convert to integer

dim_df['SR'] = pd.to_numeric(dim_df['SR'], errors='coerce').round(2)  # Or use .astype('Int64') if you want no decimals

# %%
def standardize_match_name(match_string):
    try:
        team1, team2 = match_string.split(' Vs ')
        team1_full = team_name_map.get(team1.strip(), team1.strip())
        team2_full = team_name_map.get(team2.strip(), team2.strip())
        return f"{team1_full} Vs {team2_full}"
    except:
        return match_string  # fallback if not in expected format

dim_df['match'] = dim_df['match'].apply(standardize_match_name)

# %%
dim_df.head(10)
# Out:
#   match_id                                  match          teamInnings  \
# 0  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 1  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 2  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 3  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 4  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 5  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 6  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 7  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 8  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
# 9  T203878  Chennai Super Kings Vs Mumbai Indians  Chennai Super Kings
#
#    battingPos        batsmanName out/not_out  runs  balls  4s  6s      SR
# 0           1     RuturajGaikwad         out     7      6   1   0  116.66
# 1           2        DevonConway         out     0      1   0   0    0.00
# 2           3           MoeenAli         out     0      2   0   0    0.00
# 3           4       RobinUthappa         out     1      6   0   0   16.66
# 4           5       AmbatiRayudu         out    10     14   2   0   71.42
# 5           6            MSDhoni     not_out    36     33   4   2  109.09
# 6           7         ShivamDube         out    10      9   1   0  111.11
# 7           8        DwayneBravo         out    12     15   0   1   80.00
# 8           9     SimarjeetSingh         out     2      3   0   0   66.66
# 9          10  MaheeshTheekshana         out     0      3   0   0    0.00

# %%
# Total runs by batsman
dim_df.groupby('batsmanName')['runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsmanName
# ShubmanGill        1274
# FafduPlessis       1119
# JosButtler         1017
# DavidWarner         943
# SuryakumarYadav     908
# RuturajGaikwad      903
# DevonConway         903
# ViratKohli          855
# IshanKishan         781
# ShikharDhawan       754
# Name: runs, dtype: Int64

# %%
# Count number of 'not_out' entries per batsman
not_out_counts = (
    dim_df[dim_df['out/not_out'].str.lower() == 'not_out']
    .groupby('batsmanName')
    .size()
    .sort_values(ascending=False)
)

# Display top 10 batsmen with most not outs
print(not_out_counts.head(10))
# Out:
# batsmanName
# MSDhoni           14
# ShimronHetmyer    12
# KuldeepYadav      12
# RahulTewatia      11
# DavidMiller       11
# DineshKarthik      9
# TimDavid           9
# RashidKhan         8
# RavindraJadeja     8
# RinkuSingh         8
# dtype: int64

# %%
dim_df.groupby(['teamInnings', 'batsmanName'])['runs'].sum().sort_values(ascending=False)
# Out:
# teamInnings                  batsmanName
# Gujarat Titans               ShubmanGill         1274
# Royal Challengers Bangalore  FafduPlessis        1119
# Rajasthan Royals             JosButtler          1017
# Delhi Capitals               DavidWarner          943
# Mumbai Indians               SuryakumarYadav      908
#                                                  ...
# Gujarat Titans               DarshanNalkande        0
# Chennai Super Kings          Tushar Deshpande       0
#  PBKS                         Jonny Bairstow        0
#  GT                           Mohit Sharma          0
# Lucknow Super Giants         RomarioShepherd        0
# Name: runs, Length: 530, dtype: Int64

# %%
import matplotlib.pyplot as plt

top_runs = dim_df.groupby('batsmanName')['runs'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))
plt.barh(top_runs.index[::-1], top_runs.values[::-1], color='skyblue')
plt.title('Top 10 Run Scorers')
plt.xlabel('Total Runs')
plt.ylabel('Batsman')
plt.tight_layout()
plt.show()

# %%
dim_df['runs'] = pd.to_numeric(dim_df['runs'], errors='coerce')
dim_df['balls'] = pd.to_numeric(dim_df['balls'], errors='coerce')

# Keep only batsmen who have played more than 200 balls
batsmen = dim_df.groupby('batsmanName').filter(lambda x: x['balls'].sum() > 200)

# Calculate strike rate for each batsman
strike_rate = batsmen.groupby('batsmanName').agg({'runs': 'sum', 'balls': 'sum'})
strike_rate['SR'] = (strike_rate['runs'] / strike_rate['balls']) * 100

# Pick top 10 batsmen by strike rate
top_sr = strike_rate.sort_values(by='SR', ascending=False).head(10)

# Plot bar chart
plt.figure(figsize=(12,6))
plt.barh(top_sr.index[::-1], top_sr['SR'][::-1], color='skyblue')
plt.title('Top 10 Strike Rates (Min 200 Balls Faced)')
plt.xlabel('Strike Rate')
plt.ylabel('Batsman')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

top_sixes = dim_df.groupby('batsmanName')['6s'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))
colors = plt.cm.Greens(np.linspace(0.5, 1, len(top_sixes)))  # gradient green
bars = plt.bar(top_sixes.index, top_sixes.values, color=colors)
plt.title('Top 10 Most Sixes Hit')
plt.ylabel('Number of Sixes')
plt.xlabel('Batsman')
plt.xticks(rotation=45, ha='right')

# Add value labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, int(yval), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

top_fours = dim_df.groupby('batsmanName')['4s'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))
bars = plt.bar(top_fours.index, top_fours.values, color='orange')
plt.title('Top 10 Most Fours Hit')
plt.ylabel('Number of Fours')
plt.xlabel('Batsman')
plt.xticks(rotation=45, ha='right')

# Add value labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, int(yval), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
avg_pos_runs = dim_df.groupby('battingPos')['runs'].mean()

plt.figure(figsize=(10,5))
plt.plot(avg_pos_runs.index, avg_pos_runs.values, marker='o', color='purple')
plt.title('Average Runs per Batting Position')
plt.xlabel('Batting Position')
plt.ylabel('Average Runs')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Save to Excel file
dim_df.to_excel('cleaned_ipl_data_batsman.xlsx', index=False)

# %%
from IPython.display import FileLink
FileLink('cleaned_ipl_data_batsman.xlsx')
# Out:
# C:\Users\ASUS\cleaned_ipl_data_batsman.xlsx

# %%
dim_df.columns
# Out:
# Index(['match_id', 'match', 'teamInnings', 'battingPos', 'batsmanName',
#        'out/not_out', 'runs', 'balls', '4s', '6s', 'SR'],
#       dtype='object')
